# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import ROOT
from ROOT import TFile, TTree, TH1F, TCanvas, TAxis, TLegend, TTreeReader, TTreeReaderValue
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.preprocessing import StandardScaler
import multiprocessing
import time
import concurrent.futures
# Out:
# Welcome to JupyROOT 6.22/06

# %%
from joblib import dump, load
clf = load('training_3TeV_0p03/BDT_model_matching_0_1_2_3.joblib')

# %%
def BDT_sort(event_record, evtnum, index, ismatched_arr):
    if not sum(evtnum) / 3 == evtnum[0]:
        print("Check if 3 candidates are coming from the same event")
        print(evtnum)
    best_score = 0
    best_index = -99
    score_BDT_temp = clf.predict(event_record)
#     print(score_BDT_temp)
#     print(index)
#     print(ismatched_arr)
    for i, score in enumerate(score_BDT_temp.ravel()):
        if score > best_score:
            best_score = score
            best_index = index[i]
#     print(best_score, best_index)
    return best_score, best_index

def select_trijet(sample, batch_size, ibatch, isSig):
    inFile = TFile(f"/home/xyan13/Trijet/TrijetAna/TrijetAna/outputs_3_jets/{sample}_ML_study.root","READ")
    inTree = inFile.Get("Events")
    variable2use = ['dijet_eta','dijet_phi','dR_jj','dEta_jj','dPhi_jj','dR_j0j2','dEta_j0j2','dPhi_j0j2','dR_j1j2','dEta_j1j2','dPhi_j1j2',
                    'jet_eta_0','jet_phi_0','jet_ptoverm_0','jet_eta_1','jet_phi_1','jet_ptoverm_1','jet_eta_2',
                    'jet_phi_2','jet_ptoverm_2','dR_jj_j','dEta_jj_j','dPhi_jj_j','jet_ptoverM_0','jet_ptoverM_1','jet_ptoverM_2',
                    'dijet_ptoverM']
    outFile = TFile(f"{sample}_BDT_Ranking_{ibatch}.root","RECREATE")
    outTree = TTree("Events","Events")
    
    dijet_eta = np.empty((1), dtype="float32")
    dijet_phi = np.empty((1), dtype="float32")
    dR_jj = np.empty((1), dtype="float32")
    dEta_jj = np.empty((1), dtype="float32")
    dPhi_jj = np.empty((1), dtype="float32")
    jet_eta_0 = np.empty((1), dtype="float32")
    jet_phi_0 = np.empty((1), dtype="float32")
    jet_ptoverm_0 = np.empty((1), dtype="float32")
    jet_eta_1 = np.empty((1), dtype="float32")
    jet_phi_1 = np.empty((1), dtype="float32")
    jet_ptoverm_1 = np.empty((1), dtype="float32")
    jet_eta_2 = np.empty((1), dtype="float32")
    jet_phi_2 = np.empty((1), dtype="float32")
    jet_ptoverm_2 = np.empty((1), dtype="float32")
    dR_jj_j = np.empty((1), dtype="float32")
    dEta_jj_j = np.empty((1), dtype="float32")
    dPhi_jj_j = np.empty((1), dtype="float32")
    jet_ptoverM_0 = np.empty((1), dtype="float32")
    jet_ptoverM_1 = np.empty((1), dtype="float32")
    jet_ptoverM_2 = np.empty((1), dtype="float32")
    dijet_ptoverM = np.empty((1), dtype="float32")
    M_jjj = np.empty((1), dtype="float32")
    m_jj = np.empty((1), dtype="float32")
    score_BDT = np.empty((1), dtype="float32")
    isMatched = np.empty((1), dtype="int32")

    outTree.Branch("dijet_eta", dijet_eta, "dijet_eta/F")
    outTree.Branch("dijet_phi", dijet_phi, "dijet_phi/F")
    outTree.Branch("dR_jj", dR_jj, "dR_jj/F")
    outTree.Branch("dEta_jj", dEta_jj, "dEta_jj/F")
    outTree.Branch("dPhi_jj", dPhi_jj, "dPhi_jj/F")
    outTree.Branch("jet_eta_0", jet_eta_0, "jet_eta_0/F")
    outTree.Branch("jet_phi_0", jet_phi_0, "jet_phi_0/F")
    outTree.Branch("jet_ptoverm_0", jet_ptoverm_0, "jet_ptoverm_0/F")
    outTree.Branch("jet_eta_1", jet_eta_1, "jet_eta_1/F")
    outTree.Branch("jet_phi_1", jet_phi_1, "jet_phi_1/F")
    outTree.Branch("jet_ptoverm_1", jet_ptoverm_1, "jet_ptoverm_1/F")
    outTree.Branch("jet_eta_2", jet_eta_2, "jet_eta_2/F")
    outTree.Branch("jet_phi_2", jet_phi_2, "jet_phi_2/F")
    outTree.Branch("jet_ptoverm_2", jet_ptoverm_2, "jet_ptoverm_2/F")
    outTree.Branch("dR_jj_j", dR_jj_j, "dR_jj_j/F")
    outTree.Branch("dEta_jj_j", dEta_jj_j, "dEta_jj_j/F")
    outTree.Branch("dPhi_jj_j", dPhi_jj_j, "dPhi_jj_j/F")
    outTree.Branch("jet_ptoverM_0", jet_ptoverM_0, "jet_ptoverM_0/F")
    outTree.Branch("jet_ptoverM_1", jet_ptoverM_1, "jet_ptoverM_1/F")
    outTree.Branch("jet_ptoverM_2", jet_ptoverM_2, "jet_ptoverM_2/F")
    outTree.Branch("dijet_ptoverM", dijet_ptoverM, "dijet_ptoverM/F")
    outTree.Branch("M_jjj", M_jjj, "M_jjj/F")
    outTree.Branch("m_jj", m_jj, "m_jj/F")
    outTree.Branch("score_BDT", score_BDT, "score_BDT/F")
    outTree.Branch("isMatched", isMatched, "isMatched/I")
    
    t_start = time.time()
    evtnum = []
    index = []
    event_record = []
    ismatched_arr = []
    evt_start = ibatch*batch_size
    evt_end = (ibatch+1)*batch_size
    if((ibatch+1)*batch_size > inTree.GetEntries()):
        evt_end = inTree.GetEntries()
    for ievt in range(evt_start, evt_end):
        inTree.GetEntry(ievt)
#         if ievt%1000 == 0:
#             print("Processing: ",ievt)
#             # time check:
#             t_end = time.time()
#             speed = (t_end - t_start)/(ievt+1)*1000
#             print(f"Avg. speed: {speed}s/1k candidates".format(speed))
#         if ievt > 100000: break

        if (ievt - evt_start)%100000 == 0:
            # time check:
            t_end = time.time()
            speed = (t_end - t_start)/(ievt - evt_start+1)*1000
            t_remain = (evt_end - ievt) / 1000 * speed / 60
            print(f"Batch #{ibatch} >> Avg. speed: {speed}s/1k candidates, time remaining: {t_remain}mins\n".format(ibatch, speed, t_remain))

        # make event record for BDT classification
        trijet_record = []
        for var in variable2use:
            trijet_record.append(getattr(inTree, var))
        if len(event_record) < 3:
            event_record.append(trijet_record)
            evtnum.append(inTree.evt_num)
            index.append(ievt)
            if isSig == 1:
                ismatched_arr.append(inTree.gen_dijet_matched)
            else:
                ismatched_arr.append(-99)
            if(len(event_record) == 3):
                best_score, best_index = BDT_sort(event_record, evtnum, index, ismatched_arr)
                inTree.GetEntry(best_index)
                dijet_eta[0] = inTree.dijet_eta
                dijet_phi[0] = inTree.dijet_phi
                dR_jj[0] = inTree.dR_jj
                dEta_jj[0] = inTree.dEta_jj
                dPhi_jj[0] = inTree.dPhi_jj
                jet_eta_0[0] = inTree.jet_eta_0
                jet_phi_0[0] = inTree.jet_phi_0
                jet_ptoverm_0[0] = inTree.jet_ptoverm_0
                jet_eta_1[0] = inTree.jet_eta_1
                jet_phi_1[0] = inTree.jet_phi_1
                jet_ptoverm_1[0] = inTree.jet_ptoverm_1
                jet_eta_2[0] = inTree.jet_eta_2
                jet_phi_2[0] = inTree.jet_phi_2
                jet_ptoverm_2[0] = inTree.jet_ptoverm_2
                dR_jj_j[0] = inTree.dR_jj_j
                dEta_jj_j[0] = inTree.dEta_jj_j
                dPhi_jj_j[0] = inTree.dPhi_jj_j
                jet_ptoverM_0[0] = inTree.jet_ptoverM_0
                jet_ptoverM_1[0] = inTree.jet_ptoverM_1
                jet_ptoverM_2[0] = inTree.jet_ptoverM_2
                dijet_ptoverM[0] = inTree.dijet_ptoverM
                M_jjj[0] = inTree.M_jjj
                m_jj[0] = inTree.m_jj
                score_BDT[0] = best_score
                if isSig == 1:
                    isMatched[0] = inTree.gen_dijet_matched
#                     print(isMatched[0])
                else:
                    isMatched[0] = -99
                outTree.Fill()
                event_record.clear()
                evtnum.clear()
                index.clear()
                ismatched_arr.clear()
#     print("Number of trijet candidates selected: ", outTree.GetEntries())
    outFile.cd()
    outTree.Write()
    outFile.Write()
    outFile.Close()
    print(f"Finished processing of batch {ibatch}/n")
    return 0

# %%
# QCD processing
if __name__ == '__main__':
    
#     for sample in ["QCD_Pt_300to470","QCD_Pt_470to600","QCD_Pt_600to800"]:
    for sample in ["QCD_Pt_800to1000","QCD_Pt_1000to1400","QCD_Pt_1400to1800",
                   "QCD_Pt_1800to2400","QCD_Pt_2400to3200","QCD_Pt_3200toInf"]:
        isSig = 0
        temp_file = TFile(f"/home/xyan13/Trijet/TrijetAna/TrijetAna/outputs_3_jets/{sample}_ML_study.root","READ")
        temp_tree = temp_file.Get("Events")
        tot_evts = temp_tree.GetEntries()
        print(tot_evts)
        expect_time = 0.27 # in hrs
        known_speed = 1.8 # sec per 1k candidates
        evt_batch = int(expect_time * 3600 / known_speed * 1000)
        if(evt_batch%3 != 0):
            print("!!!!")
        num_batch = math.ceil(tot_evts / evt_batch)
        print(f"Number of Candidates to be processed: {tot_evts}")
        print(f"Candidates to be processed per batch: {evt_batch}")
        print(f"Number of batches to be processed: {num_batch}")

        main_start = time.time()

    #     multiprocessing way
    #     p1 = multiprocessing.Process(target=select_trijet, args=(sample, ibatch_1))
    #     p2 = multiprocessing.Process(target=select_trijet, args=(sample, ibatch_2))
    #     p1.start()
    #     p1.join()
    #     p2.start()
    #     p2.join()
        with concurrent.futures.ProcessPoolExecutor() as executor:
            results = [executor.submit(select_trijet, sample, evt_batch, ibatch, isSig) for ibatch in range(num_batch)]
            status = [r.result() for r in results]
            print(status)

        print(f"Time used: {round(time.time() - main_start, 2)}")
# Out:
# 2863974
# Number of Candidates to be processed: 2863974
# Candidates to be processed per batch: 540000
# Number of batches to be processed: 6
# Batch #0 >> Avg. speed: 104.36630249023438s/1k candidates, time remaining: 939.2967224121094mins
#
# Batch #4 >> Avg. speed: 588.3364677429199s/1k candidates, time remaining: 5295.028209686279mins
#
# Batch #5 >> Avg. speed: 595.8046913146973s/1k candidates, time remaining: 1628.274640893936mins
#
# Batch #1 >> Avg. speed: 599.083423614502s/1k candidates, time remaining: 5391.750812530518mins
# Batch #3 >> Avg. speed: 600.4796028137207s/1k candidates, time remaining: 5404.316425323486mins
#
# Batch #2 >> Avg. speed: 602.2970676422119s/1k candidates, time remaining: 5420.673608779907mins
#
#
# Batch #0 >> Avg. speed: 1.4061223442445447s/1k candidates, time remaining: 10.311563857793328mins
#
# Batch #1 >> Avg. speed: 1.4124973238869296s/1k candidates, time remaining: 10.35831370850415mins
#
# Batch #2 >> Avg. speed: 1.424851459836537s/1k candidates, time remaining: 10.448910705467938mins
#
# Batch #5 >> Avg. speed: 1.443191182178144s/1k candidates, time remaining: 1.5387785448110765mins
#
# Batch #4 >> Avg. speed: 1.4483931875196934s/1k candidates, time remaining: 10.621550041811084mins
#
# Batch #3 >> Avg. speed: 1.4546354504030032s/1k candidates, time remaining: 10.66732663628869mins
#
# Finished processing of batch 5/n
# Batch #2 >> Avg. speed: 1.4076167381137428s/1k candidates, time remaining: 7.976494849311209mins
#
# Batch #0 >> Avg. speed: 1.4186819381912612s/1k candidates, time remaining: 8.03919764975048mins
#
# Batch #1 >> Avg. speed: 1.4228546716153139s/1k candidates, time remaining: 8.062843139153445mins
#
# Batch #3 >> Avg. speed: 1.4460781487329442s/1k candidates, time remaining: 8.194442842820017mins
#
# Batch #4 >> Avg. speed: 1.448387548950088s/1k candidates, time remaining: 8.207529444050499mins
#
# Batch #2 >> Avg. speed: 1.3935121863573892s/1k candidates, time remaining: 5.574048745429557mins
#
# Batch #1 >> Avg. speed: 1.416389795327676s/1k candidates, time remaining: 5.665559181310704mins
#
# Batch #0 >> Avg. speed: 1.4239853806276497s/1k candidates, time remaining: 5.695941522510599mins
#
# Batch #3 >> Avg. speed: 1.4392048760551068s/1k candidates, time remaining: 5.756819504220427mins
#
# Batch #4 >> Avg. speed: 1.4429533106606462s/1k candidates, time remaining: 5.771813242642585mins
#
# Batch #2 >> Avg. speed: 1.3946530767685303s/1k candidates, time remaining: 3.254190512459904mins
#
# Batch #1 >> Avg. speed: 1.4146868058284947s/1k candidates, time remaining: 3.3009358802664877mins
#
# Batch #0 >> Avg. speed: 1.4238196242258876s/1k candidates, time remaining: 3.3222457898604043mins
#
# Batch #3 >> Avg. speed: 1.4288044697998148s/1k candidates, time remaining: 3.3338770961995676mins
#
# Batch #4 >> Avg. speed: 1.4390388096772222s/1k candidates, time remaining: 3.357757222580185mins
#
# Batch #2 >> Avg. speed: 1.403477951711089s/1k candidates, time remaining: 0.9356519678073927mins
#
# Batch #1 >> Avg. speed: 1.4099402305040605s/1k candidates, time remaining: 0.9399601536693737mins
#
# Batch #0 >> Avg. speed: 1.4245918120521852s/1k candidates, time remaining: 0.9497278747014568mins
#
# Batch #3 >> Avg. speed: 1.4257797202331621s/1k candidates, time remaining: 0.9505198134887748mins
#
# Batch #4 >> Avg. speed: 1.4394974929379976s/1k candidates, time remaining: 0.9596649952919983mins
#
# Finished processing of batch 2/n
# Finished processing of batch 1/n
# Finished processing of batch 3/n
# Finished processing of batch 0/n
# Finished processing of batch 4/n
# [0, 0, 0, 0, 0, 0]
# Time used: 777.82
# 2369250
# Number of Candidates to be processed: 2369250
# Candidates to be processed per batch: 540000
# Number of batches to be processed: 5
# Batch #0 >> Avg. speed: 43.385982513427734s/1k candidates, time remaining: 390.4738426208496mins
#
# Batch #3 >> Avg. speed: 430.4373264312744s/1k candidates, time remaining: 3873.9359378814697mins
#
# Batch #1 >> Avg. speed: 451.432466506958s/1k candidates, time remaining: 4062.892198562622mins
#
# Batch #4 >> Avg. speed: 453.28664779663086s/1k candidates, time remaining: 1580.8371841907501mins
# Batch #2 >> Avg. speed: 453.5021781921387s/1k candidates, time remaining: 4081.519603729248mins
#
#
# Batch #3 >> Avg. speed: 1.3980861210865734s/1k candidates, time remaining: 10.25263155463487mins
#
# Batch #4 >> Avg. speed: 1.4292187390854973s/1k candidates, time remaining: 2.60236912075151mins
#
# Batch #0 >> Avg. speed: 1.4380603273816506s/1k candidates, time remaining: 10.545775734132103mins
#
# Batch #1 >> Avg. speed: 1.4439308898804017s/1k candidates, time remaining: 10.588826525789614mins
#
# Batch #2 >> Avg. speed: 1.4458285731206713s/1k candidates, time remaining: 10.602742869551589mins
#
# Batch #3 >> Avg. speed: 1.397927188477995s/1k candidates, time remaining: 7.921587401375304mins
#
# Batch #4 >> Avg. speed: 1.4286387882883738s/1k candidates, time remaining: 0.2202484798611243mins
#
# Batch #1 >> Avg. speed: 1.438147480454767s/1k candidates, time remaining: 8.149502389243679mins
#
# Batch #0 >> Avg. speed: 1.439593729861093s/1k candidates, time remaining: 8.157697802546194mins
#
# Batch #2 >> Avg. speed: 1.4436465321869558s/1k candidates, time remaining: 8.18066368239275mins
#
# Finished processing of batch 4/n
# Batch #3 >> Avg. speed: 1.3960555136352975s/1k candidates, time remaining: 5.58422205454119mins
#
# Batch #1 >> Avg. speed: 1.4318194830527424s/1k candidates, time remaining: 5.72727793221097mins
#
# Batch #0 >> Avg. speed: 1.4323916420253167s/1k candidates, time remaining: 5.729566568101267mins
#
# Batch #2 >> Avg. speed: 1.4415426411087786s/1k candidates, time remaining: 5.766170564435114mins
#
# Batch #3 >> Avg. speed: 1.3979687115515718s/1k candidates, time remaining: 3.2619269936203343mins
#
# Batch #0 >> Avg. speed: 1.4285163202096725s/1k candidates, time remaining: 3.3332047471559023mins
#
# Batch #1 >> Avg. speed: 1.4318176594504497s/1k candidates, time remaining: 3.340907872051049mins
#
# Batch #2 >> Avg. speed: 1.4369570880920515s/1k candidates, time remaining: 3.3528998722147865mins
#
# Batch #3 >> Avg. speed: 1.401437812778366s/1k candidates, time remaining: 0.9342918751855773mins
#
# Batch #0 >> Avg. speed: 1.4300457639471684s/1k candidates, time remaining: 0.9533638426314456mins
#
# Batch #1 >> Avg. speed: 1.4316355873513837s/1k candidates, time remaining: 0.9544237249009224mins
#
# Batch #2 >> Avg. speed: 1.4380715333417966s/1k candidates, time remaining: 0.9587143555611977mins
#
# Finished processing of batch 3/n
# Finished processing of batch 0/n
# Finished processing of batch 1/n
# Finished processing of batch 2/n
# [0, 0, 0, 0, 0]
# Time used: 776.42
# 1234140
# Number of Candidates to be processed: 1234140
# Candidates to be processed per batch: 540000
# Number of batches to be processed: 3
# Batch #0 >> Avg. speed: 21.376371383666992s/1k candidates, time remaining: 192.38734245300293mins
#
# Batch #1 >> Avg. speed: 373.9645481109619s/1k candidates, time remaining: 3365.680932998657mins
# Batch #2 >> Avg. speed: 373.5339641571045s/1k candidates, time remaining: 959.6087539196013mins
#
#
# Batch #0 >> Avg. speed: 1.4041177980973791s/1k candidates, time remaining: 10.296863852714115mins
#
# Batch #2 >> Avg. speed: 1.4099818089190934s/1k candidates, time remaining: 1.2722735855813285mins
#
# Batch #1 >> Avg. speed: 1.4118531495539843s/1k candidates, time remaining: 10.353589763395885mins
#
# Finished processing of batch 2/n
# Batch #1 >> Avg. speed: 1.3997279108949s/1k candidates, time remaining: 7.931791495071099mins
#
# Batch #0 >> Avg. speed: 1.4021650491875715s/1k candidates, time remaining: 7.945601945396238mins
#
# Batch #1 >> Avg. speed: 1.3954911111879749s/1k candidates, time remaining: 5.5819644447518995mins
#
# Batch #0 >> Avg. speed: 1.3976298959377105s/1k candidates, time remaining: 5.590519583750842mins
#
# Batch #1 >> Avg. speed: 1.393991820320208s/1k candidates, time remaining: 3.2526475807471518mins
#
# Batch #0 >> Avg. speed: 1.3970916433173013s/1k candidates, time remaining: 3.259880501073703mins
#
# Batch #1 >> Avg. speed: 1.3879858662439963s/1k candidates, time remaining: 0.9253239108293309mins
#
# Batch #0 >> Avg. speed: 1.3939569217304741s/1k candidates, time remaining: 0.9293046144869828mins
#
# Finished processing of batch 1/n
# Finished processing of batch 0/n
# [0, 0, 0]
# Time used: 752.36
# 1340877
# Number of Candidates to be processed: 1340877
# Candidates to be processed per batch: 540000
# Number of batches to be processed: 3
# Batch #0 >> Avg. speed: 26.18241310119629s/1k candidates, time remaining: 235.6417179107666mins
#
# Batch #2 >> Avg. speed: 379.7435760498047s/1k candidates, time remaining: 1651.1060814857483mins
#
# Batch #1 >> Avg. speed: 375.4429817199707s/1k candidates, time remaining: 3378.9868354797363mins
#
# Batch #0 >> Avg. speed: 1.3905481210194917s/1k candidates, time remaining: 10.197352887476272mins
#
# Batch #1 >> Avg. speed: 1.407257541499292s/1k candidates, time remaining: 10.319888637661474mins
#
# Batch #2 >> Avg. speed: 1.4133072451585968s/1k candidates, time remaining: 3.7894771613229934mins
#
# Batch #0 >> Avg. speed: 1.400342616483405s/1k candidates, time remaining: 7.9352748267392945mins
#
# Batch #1 >> Avg. speed: 1.4048558230490706s/1k candidates, time remaining: 7.9608496639447335mins
#
# Batch #2 >> Avg. speed: 1.4144929065546321s/1k candidates, time remaining: 1.4351680778721057mins
#
# Finished processing of batch 2/n
# Batch #1 >> Avg. speed: 1.3951885995506257s/1k candidates, time remaining: 5.580754398202503mins
#
# Batch #0 >> Avg. speed: 1.395909823679799s/1k candidates, time remaining: 5.583639294719196mins
#
# Batch #1 >> Avg. speed: 1.388704185099889s/1k candidates, time remaining: 3.240309765233074mins
#
# Batch #0 >> Avg. speed: 1.3910808476114491s/1k candidates, time remaining: 3.245855311093381mins
#
# Batch #1 >> Avg. speed: 1.3830561299524984s/1k candidates, time remaining: 0.9220374199683322mins
#
# Batch #0 >> Avg. speed: 1.3851156327266507s/1k candidates, time remaining: 0.9234104218177671mins
#
# Finished processing of batch 1/n
# Finished processing of batch 0/n
# [0, 0, 0]
# Time used: 747.8
# 2244453
# Number of Candidates to be processed: 2244453
# Candidates to be processed per batch: 540000
# Number of batches to be processed: 5
# Batch #0 >> Avg. speed: 21.784305572509766s/1k candidates, time remaining: 196.0587501525879mins
#
# Batch #1 >> Avg. speed: 376.27196311950684s/1k candidates, time remaining: 3386.4476680755615mins
#
# Batch #2 >> Avg. speed: 385.79583168029785s/1k candidates, time remaining: 3472.1624851226807mins
# Batch #4 >> Avg. speed: 384.1822147369385s/1k candidates, time remaining: 540.7556763529777mins
# Batch #3 >> Avg. speed: 385.0586414337158s/1k candidates, time remaining: 3465.5277729034424mins
#
#
#
# Finished processing of batch 4/n
# Batch #0 >> Avg. speed: 1.381858129660891s/1k candidates, time remaining: 10.133626284179867mins
#
# Batch #3 >> Avg. speed: 1.4305106473051785s/1k candidates, time remaining: 10.490411413571309mins
#
# Batch #1 >> Avg. speed: 1.4352618290795547s/1k candidates, time remaining: 10.525253413250066mins
#
# Batch #2 >> Avg. speed: 1.436079341522869s/1k candidates, time remaining: 10.53124850450104mins
#
# Batch #0 >> Avg. speed: 1.3666396366332834s/1k candidates, time remaining: 7.744291274255272mins
#
# Batch #3 >> Avg. speed: 1.4180298666377762s/1k candidates, time remaining: 8.035502577614064mins
#
# Batch #1 >> Avg. speed: 1.4229624756131132s/1k candidates, time remaining: 8.063454028474307mins
#
# Batch #2 >> Avg. speed: 1.4258858947766877s/1k candidates, time remaining: 8.08002007040123mins
#
# Batch #0 >> Avg. speed: 1.3727815947029323s/1k candidates, time remaining: 5.491126378811729mins
#
# Batch #3 >> Avg. speed: 1.4094082892045776s/1k candidates, time remaining: 5.6376331568183105mins
#
# Batch #1 >> Avg. speed: 1.4217738943481986s/1k candidates, time remaining: 5.687095577392794mins
#
# Batch #2 >> Avg. speed: 1.4245941891820382s/1k candidates, time remaining: 5.698376756728153mins
#
# Batch #0 >> Avg. speed: 1.376683612329017s/1k candidates, time remaining: 3.2122617621010394mins
#
# Batch #3 >> Avg. speed: 1.407505104837244s/1k candidates, time remaining: 3.2841785779535693mins
#
# Batch #1 >> Avg. speed: 1.4229045718346016s/1k candidates, time remaining: 3.320110667614071mins
#
# Batch #2 >> Avg. speed: 1.4247902893998563s/1k candidates, time remaining: 3.3245106752663314mins
#
# Batch #0 >> Avg. speed: 1.3744418602814712s/1k candidates, time remaining: 0.9162945735209808mins
#
# Batch #3 >> Avg. speed: 1.409881697906282s/1k candidates, time remaining: 0.9399211319375215mins
#
# Batch #1 >> Avg. speed: 1.4233774151432106s/1k candidates, time remaining: 0.9489182767621405mins
#
# Batch #2 >> Avg. speed: 1.4239014223692743s/1k candidates, time remaining: 0.9492676149128496mins
#
# Finished processing of batch 0/n
# Finished processing of batch 3/n
# Finished processing of batch 1/n
# Finished processing of batch 2/n
# [0, 0, 0, 0, 0]
# Time used: 768.69
# 1103238
# Number of Candidates to be processed: 1103238
# Candidates to be processed per batch: 540000
# Number of batches to be processed: 3
# Batch #0 >> Avg. speed: 24.115800857543945s/1k candidates, time remaining: 217.0422077178955mins
#
# Batch #2 >> Avg. speed: 392.9784297943115s/1k candidates, time remaining: 152.20054585933684mins
# Batch #1 >> Avg. speed: 392.9908275604248s/1k candidates, time remaining: 3536.9174480438232mins
#
#
# Finished processing of batch 2/n
# Batch #0 >> Avg. speed: 1.3362822418833917s/1k candidates, time remaining: 9.799403107144874mins
#
# Batch #1 >> Avg. speed: 1.3720762159710862s/1k candidates, time remaining: 10.061892250454632mins
#
# Batch #0 >> Avg. speed: 1.3455774345865057s/1k candidates, time remaining: 7.624938795990199mins
#
# Batch #1 >> Avg. speed: 1.3623706636467887s/1k candidates, time remaining: 7.720100427331802mins
#
# Batch #0 >> Avg. speed: 1.3524628014245526s/1k candidates, time remaining: 5.409851205698211mins
#
# Batch #1 >> Avg. speed: 1.3569534091352526s/1k candidates, time remaining: 5.4278136365410115mins
#
# Batch #0 >> Avg. speed: 1.3503489829455968s/1k candidates, time remaining: 3.150814293539726mins
#
# Batch #1 >> Avg. speed: 1.355410392878513s/1k candidates, time remaining: 3.162624250049864mins
#
# Batch #0 >> Avg. speed: 1.3534887037548617s/1k candidates, time remaining: 0.9023258025032412mins
#
# Batch #1 >> Avg. speed: 1.3549041901206664s/1k candidates, time remaining: 0.9032694600804443mins
#
# Finished processing of batch 0/n
# Finished processing of batch 1/n
# [0, 0, 0]
# Time used: 731.69

# %%
# Signal processing
if __name__ == '__main__':
    
    sample = "Res1ToRes2GluTo3Glu_M1-3000_R-0p3"
    isSig = 1
    temp_file = TFile(f"/home/xyan13/Trijet/TrijetAna/TrijetAna/outputs_3_jets/{sample}_ML_study.root","READ")
    temp_tree = temp_file.Get("Events")
    tot_evts = temp_tree.GetEntries()
    
    expect_time = 2 # in mins
    known_speed = 1.8 # sec per 1k candidates
    evt_batch = int(expect_time * 60 / known_speed * 1000)
    num_batch = math.ceil(tot_evts / evt_batch)
    print(f"Number of Candidates to be processed: {tot_evts}")
    print(f"Candidates to be processed per batch: {evt_batch}")
    print(f"Number of batches to be processed: {num_batch}")
    
    main_start = time.time()
    
    batch_size = evt_batch
    
#     multiprocessing way
#     p1 = multiprocessing.Process(target=select_trijet, args=(sample, ibatch_1))
#     p2 = multiprocessing.Process(target=select_trijet, args=(sample, ibatch_2))
#     p1.start()
#     p1.join()
#     p2.start()
#     p2.join()

    with concurrent.futures.ProcessPoolExecutor() as executor:
        results = [executor.submit(select_trijet, sample, batch_size, ibatch, isSig) for ibatch in range(num_batch)]
        status = [r.result() for r in results]
        print(status)

    print(f"Time used: {round(time.time() - main_start, 2)}")

# %%
# Dry-run, speed calculation
sample = "QCD_Pt_300to470"
isSig = 0
temp_file = TFile(f"/home/xyan13/Trijet/TrijetAna/TrijetAna/outputs_3_jets/{sample}_ML_study.root","READ")
temp_tree = temp_file.Get("Events")
tot_evts = temp_tree.GetEntries()

main_start = time.time()

batch_size = evt_batch

select_trijet(sample, 100000, 0, isSig)

print(f"Time used: {round(time.time() - main_start, 2)}")
