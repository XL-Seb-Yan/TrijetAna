# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import ROOT
from ROOT import TFile, TTree, TH1F, TCanvas, TAxis, TLegend, TTreeReader, TTreeReaderValue
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.preprocessing import StandardScaler
import multiprocessing
import time
import concurrent.futures
# Out:
# Welcome to JupyROOT 6.22/06

# %%
from joblib import dump, load
clf = load('BDT_model_matching2-3.joblib')

# %%
def BDT_sort(event_record, evtnum, index, ismatched_arr):
    if not sum(evtnum) / 3 == evtnum[0]:
        print("Check if 3 candidates are coming from the same event")
        print(evtnum)
    best_score = 0
    best_index = -99
    score_BDT_temp = clf.predict(event_record)
#     print(score_BDT_temp)
#     print(index)
#     print(ismatched_arr)
    for i, score in enumerate(score_BDT_temp.ravel()):
        if score > best_score:
            best_score = score
            best_index = index[i]
#     print(best_score, best_index)
    return best_score, best_index

def select_trijet(sample, batch_size, ibatch, isSig):
    inFile = TFile(f"/home/xyan13/Trijet/TrijetAna/TrijetAna/outputs_3_jets/{sample}_ML_study.root","READ")
    inTree = inFile.Get("Events")
    variable2use = ['dijet_eta','dijet_phi','dR_jj','dEta_jj','dPhi_jj','dR_j0j2','dEta_j0j2','dPhi_j0j2','dR_j1j2','dEta_j1j2','dPhi_j1j2',
                    'jet_eta_0','jet_phi_0','jet_ptoverm_0','jet_eta_1','jet_phi_1','jet_ptoverm_1','jet_eta_2',
                    'jet_phi_2','jet_ptoverm_2','dR_jj_j','dEta_jj_j','dPhi_jj_j','jet_ptoverM_0','jet_ptoverM_1','jet_ptoverM_2',
                    'dijet_ptoverM']
    outFile = TFile(f"{sample}_BDT_Ranking_{ibatch}.root","RECREATE")
    outTree = TTree("Events","Events")
    
    dijet_eta = np.empty((1), dtype="float32")
    dijet_phi = np.empty((1), dtype="float32")
    dR_jj = np.empty((1), dtype="float32")
    dEta_jj = np.empty((1), dtype="float32")
    dPhi_jj = np.empty((1), dtype="float32")
    jet_eta_0 = np.empty((1), dtype="float32")
    jet_phi_0 = np.empty((1), dtype="float32")
    jet_ptoverm_0 = np.empty((1), dtype="float32")
    jet_eta_1 = np.empty((1), dtype="float32")
    jet_phi_1 = np.empty((1), dtype="float32")
    jet_ptoverm_1 = np.empty((1), dtype="float32")
    jet_eta_2 = np.empty((1), dtype="float32")
    jet_phi_2 = np.empty((1), dtype="float32")
    jet_ptoverm_2 = np.empty((1), dtype="float32")
    dR_jj_j = np.empty((1), dtype="float32")
    dEta_jj_j = np.empty((1), dtype="float32")
    dPhi_jj_j = np.empty((1), dtype="float32")
    jet_ptoverM_0 = np.empty((1), dtype="float32")
    jet_ptoverM_1 = np.empty((1), dtype="float32")
    jet_ptoverM_2 = np.empty((1), dtype="float32")
    dijet_ptoverM = np.empty((1), dtype="float32")
    M_jjj = np.empty((1), dtype="float32")
    m_jj = np.empty((1), dtype="float32")
    score_BDT = np.empty((1), dtype="float32")
    isMatched = np.empty((1), dtype="int32")

    outTree.Branch("dijet_eta", dijet_eta, "dijet_eta/F")
    outTree.Branch("dijet_phi", dijet_phi, "dijet_phi/F")
    outTree.Branch("dR_jj", dR_jj, "dR_jj/F")
    outTree.Branch("dEta_jj", dEta_jj, "dEta_jj/F")
    outTree.Branch("dPhi_jj", dPhi_jj, "dPhi_jj/F")
    outTree.Branch("jet_eta_0", jet_eta_0, "jet_eta_0/F")
    outTree.Branch("jet_phi_0", jet_phi_0, "jet_phi_0/F")
    outTree.Branch("jet_ptoverm_0", jet_ptoverm_0, "jet_ptoverm_0/F")
    outTree.Branch("jet_eta_1", jet_eta_1, "jet_eta_1/F")
    outTree.Branch("jet_phi_1", jet_phi_1, "jet_phi_1/F")
    outTree.Branch("jet_ptoverm_1", jet_ptoverm_1, "jet_ptoverm_1/F")
    outTree.Branch("jet_eta_2", jet_eta_2, "jet_eta_2/F")
    outTree.Branch("jet_phi_2", jet_phi_2, "jet_phi_2/F")
    outTree.Branch("jet_ptoverm_2", jet_ptoverm_2, "jet_ptoverm_2/F")
    outTree.Branch("dR_jj_j", dR_jj_j, "dR_jj_j/F")
    outTree.Branch("dEta_jj_j", dEta_jj_j, "dEta_jj_j/F")
    outTree.Branch("dPhi_jj_j", dPhi_jj_j, "dPhi_jj_j/F")
    outTree.Branch("jet_ptoverM_0", jet_ptoverM_0, "jet_ptoverM_0/F")
    outTree.Branch("jet_ptoverM_1", jet_ptoverM_1, "jet_ptoverM_1/F")
    outTree.Branch("jet_ptoverM_2", jet_ptoverM_2, "jet_ptoverM_2/F")
    outTree.Branch("dijet_ptoverM", dijet_ptoverM, "dijet_ptoverM/F")
    outTree.Branch("M_jjj", M_jjj, "M_jjj/F")
    outTree.Branch("m_jj", m_jj, "m_jj/F")
    outTree.Branch("score_BDT", score_BDT, "score_BDT/F")
    outTree.Branch("isMatched", isMatched, "isMatched/I")
    
    t_start = time.time()
    evtnum = []
    index = []
    event_record = []
    ismatched_arr = []
    evt_start = ibatch*batch_size
    evt_end = (ibatch+1)*batch_size
    if((ibatch+1)*batch_size > inTree.GetEntries()):
        evt_end = inTree.GetEntries()
    for ievt in range(evt_start, evt_end):
        inTree.GetEntry(ievt)
#         if ievt%1000 == 0:
#             print("Processing: ",ievt)
#             # time check:
#             t_end = time.time()
#             speed = (t_end - t_start)/(ievt+1)*1000
#             print(f"Avg. speed: {speed}s/1k candidates".format(speed))
#         if ievt > 100000: break

        if (ievt - evt_start)%100000 == 0:
            # time check:
            t_end = time.time()
            speed = (t_end - t_start)/(ievt - evt_start+1)*1000
            t_remain = (evt_end - ievt) / 1000 * speed / 60
            print(f"Batch #{ibatch} >> Avg. speed: {speed}s/1k candidates, time remaining: {t_remain}mins\n".format(ibatch, speed, t_remain))

        # make event record for BDT classification
        trijet_record = []
        for var in variable2use:
            trijet_record.append(getattr(inTree, var))
        if len(event_record) < 3:
            event_record.append(trijet_record)
            evtnum.append(inTree.evt_num)
            index.append(ievt)
            if isSig == 1:
                ismatched_arr.append(inTree.gen_dijet_matched)
            else:
                ismatched_arr.append(-99)
            if(len(event_record) == 3):
                best_score, best_index = BDT_sort(event_record, evtnum, index, ismatched_arr)
                inTree.GetEntry(best_index)
                dijet_eta[0] = inTree.dijet_eta
                dijet_phi[0] = inTree.dijet_phi
                dR_jj[0] = inTree.dR_jj
                dEta_jj[0] = inTree.dEta_jj
                dPhi_jj[0] = inTree.dPhi_jj
                jet_eta_0[0] = inTree.jet_eta_0
                jet_phi_0[0] = inTree.jet_phi_0
                jet_ptoverm_0[0] = inTree.jet_ptoverm_0
                jet_eta_1[0] = inTree.jet_eta_1
                jet_phi_1[0] = inTree.jet_phi_1
                jet_ptoverm_1[0] = inTree.jet_ptoverm_1
                jet_eta_2[0] = inTree.jet_eta_2
                jet_phi_2[0] = inTree.jet_phi_2
                jet_ptoverm_2[0] = inTree.jet_ptoverm_2
                dR_jj_j[0] = inTree.dR_jj_j
                dEta_jj_j[0] = inTree.dEta_jj_j
                dPhi_jj_j[0] = inTree.dPhi_jj_j
                jet_ptoverM_0[0] = inTree.jet_ptoverM_0
                jet_ptoverM_1[0] = inTree.jet_ptoverM_1
                jet_ptoverM_2[0] = inTree.jet_ptoverM_2
                dijet_ptoverM[0] = inTree.dijet_ptoverM
                M_jjj[0] = inTree.M_jjj
                m_jj[0] = inTree.m_jj
                score_BDT[0] = best_score
                if isSig == 1:
                    isMatched[0] = inTree.gen_dijet_matched
#                     print(isMatched[0])
                else:
                    isMatched[0] = -99
                outTree.Fill()
                event_record.clear()
                evtnum.clear()
                index.clear()
                ismatched_arr.clear()
#     print("Number of trijet candidates selected: ", outTree.GetEntries())
    outFile.cd()
    outTree.Write()
    outFile.Write()
    outFile.Close()
    print(f"Finished processing of batch {ibatch}/n")
    return 0

# %%
# QCD processing
if __name__ == '__main__':
    
#     for sample in ["QCD_Pt_300to470","QCD_Pt_470to600","QCD_Pt_600to800"]:
    for sample in ["QCD_Pt_800to1000","QCD_Pt_1000to1400","QCD_Pt_1400to1800",
                   "QCD_Pt_1800to2400","QCD_Pt_2400to3200","QCD_Pt_3200toInf"]:
        isSig = 0
        temp_file = TFile(f"/home/xyan13/Trijet/TrijetAna/TrijetAna/outputs_3_jets/{sample}_ML_study.root","READ")
        temp_tree = temp_file.Get("Events")
        tot_evts = temp_tree.GetEntries()
        print(tot_evts)
        expect_time = 0.3 # in hrs
        known_speed = 1.75 # sec per 1k candidates
        evt_batch = int(expect_time * 3600 / known_speed * 1000)
        if(evt_batch%3 != 0):
            print("!!!!")
        num_batch = math.ceil(tot_evts / evt_batch)
        print(f"Number of Candidates to be processed: {tot_evts}")
        print(f"Candidates to be processed per batch: {evt_batch}")
        print(f"Number of batches to be processed: {num_batch}")

        main_start = time.time()

    #     multiprocessing way
    #     p1 = multiprocessing.Process(target=select_trijet, args=(sample, ibatch_1))
    #     p2 = multiprocessing.Process(target=select_trijet, args=(sample, ibatch_2))
    #     p1.start()
    #     p1.join()
    #     p2.start()
    #     p2.join()
        with concurrent.futures.ProcessPoolExecutor() as executor:
            results = [executor.submit(select_trijet, sample, evt_batch, ibatch, isSig) for ibatch in range(num_batch)]
            status = [r.result() for r in results]
            print(status)

        print(f"Time used: {round(time.time() - main_start, 2)}")
# Out:
# 2863974
# Number of Candidates to be processed: 2863974
# Candidates to be processed per batch: 617142
# Number of batches to be processed: 5
# Batch #0 >> Avg. speed: 95.42965888977051s/1k candidates, time remaining: 981.5608424425126mins
#
# Batch #2 >> Avg. speed: 1682.3830604553223s/1k candidates, time remaining: 17304.48744492531mins
#
# Batch #1 >> Avg. speed: 1694.0875053405762s/1k candidates, time remaining: 17424.875853681566mins
#
# Batch #3 >> Avg. speed: 1732.637643814087s/1k candidates, time remaining: 17821.391012978554mins
#
# Batch #4 >> Avg. speed: 1789.4392013549805s/1k candidates, time remaining: 11792.583280849456mins
#
# Batch #4 >> Avg. speed: 1.00979865693439s/1k candidates, time remaining: 4.9716763675060065mins
#
# Batch #0 >> Avg. speed: 1.0215360650234135s/1k candidates, time remaining: 8.80465339563897mins
#
# Batch #1 >> Avg. speed: 1.0348930438613093s/1k candidates, time remaining: 8.919777641475422mins
#
# Batch #2 >> Avg. speed: 1.0359763903619814s/1k candidates, time remaining: 8.929115041076265mins
#
# Batch #3 >> Avg. speed: 1.036103516261285s/1k candidates, time remaining: 8.930210743439892mins
#
# Batch #4 >> Avg. speed: 1.007676480410704s/1k candidates, time remaining: 3.281767172185567mins
#
# Batch #0 >> Avg. speed: 1.0100067111549513s/1k candidates, time remaining: 7.021936991743312mins
#
# Batch #2 >> Avg. speed: 1.0242242444660121s/1k candidates, time remaining: 7.120782496417354mins
#
# Batch #1 >> Avg. speed: 1.027274141669224s/1k candidates, time remaining: 7.141986500069724mins
#
# Batch #3 >> Avg. speed: 1.1009520760444447s/1k candidates, time remaining: 7.654222515088862mins
#
# Batch #0 >> Avg. speed: 1.0158154522269451s/1k candidates, time remaining: 5.369295735835964mins
#
# Batch #1 >> Avg. speed: 1.018609575940594s/1k candidates, time remaining: 5.384064635549198mins
#
# Batch #2 >> Avg. speed: 1.0237423381117314s/1k candidates, time remaining: 5.411194876557179mins
#
# Batch #4 >> Avg. speed: 1.0533525617274735s/1k candidates, time remaining: 1.6749359084028557mins
#
# Batch #3 >> Avg. speed: 1.0751121486447766s/1k candidates, time remaining: 5.682720284091696mins
#
# Batch #1 >> Avg. speed: 1.0197527252716214s/1k candidates, time remaining: 3.690519104515507mins
#
# Batch #2 >> Avg. speed: 1.0220352198324139s/1k candidates, time remaining: 3.6987795284141667mins
#
# Finished processing of batch 4/n
# Batch #0 >> Avg. speed: 1.0284564771299864s/1k candidates, time remaining: 3.722018272615992mins
#
# Batch #3 >> Avg. speed: 1.0654769975337788s/1k candidates, time remaining: 3.8559967699746633mins
#
# Batch #2 >> Avg. speed: 1.0162019146634313s/1k candidates, time remaining: 1.9839987447917278mins
#
# Batch #1 >> Avg. speed: 1.018115331990619s/1k candidates, time remaining: 1.9877344370007515mins
#
# Batch #0 >> Avg. speed: 1.0266844610086718s/1k candidates, time remaining: 2.0044645188579637mins
#
# Batch #3 >> Avg. speed: 1.062705506653806s/1k candidates, time remaining: 2.0747908076740025mins
#
# Batch #2 >> Avg. speed: 1.020490185719304s/1k candidates, time remaining: 0.2915540460600052mins
#
# Batch #0 >> Avg. speed: 1.0248990055966383s/1k candidates, time remaining: 0.2928136458989596mins
#
# Batch #1 >> Avg. speed: 1.0384304497667196s/1k candidates, time remaining: 0.2966795794983518mins
#
# Finished processing of batch 2/n
# Finished processing of batch 0/n
# Batch #3 >> Avg. speed: 1.0607210004383982s/1k candidates, time remaining: 0.3030479898252504mins
#
# Finished processing of batch 1/n
# Finished processing of batch 3/n
# [0, 0, 0, 0, 0]
# Time used: 653.77
# 2369250
# Number of Candidates to be processed: 2369250
# Candidates to be processed per batch: 617142
# Number of batches to be processed: 4
# Batch #0 >> Avg. speed: 66.71738624572754s/1k candidates, time remaining: 686.2350197076797mins
#
# Batch #2 >> Avg. speed: 1484.5845699310303s/1k candidates, time remaining: 15269.9915109396mins
#
# Batch #1 >> Avg. speed: 1555.4769039154053s/1k candidates, time remaining: 15999.168790602685mins
#
# Batch #3 >> Avg. speed: 1582.1712017059326s/1k candidates, time remaining: 13654.77033920288mins
#
# Batch #0 >> Avg. speed: 0.992459173976223s/1k candidates, time remaining: 8.554038702473532mins
#
# Batch #3 >> Avg. speed: 1.0295491165113984s/1k candidates, time remaining: 7.169505500954309mins
#
# Batch #1 >> Avg. speed: 1.0338199063421047s/1k candidates, time remaining: 8.910528233426145mins
#
# Batch #2 >> Avg. speed: 1.263107478960153s/1k candidates, time remaining: 10.886765464740192mins
#
# Batch #0 >> Avg. speed: 0.9963052275097359s/1k candidates, time remaining: 6.926679253564438mins
#
# Batch #3 >> Avg. speed: 1.0129428737278614s/1k candidates, time remaining: 5.3656259316613975mins
#
# Batch #1 >> Avg. speed: 1.0172895099860897s/1k candidates, time remaining: 7.072569679576957mins
#
# Batch #2 >> Avg. speed: 1.1657317907410707s/1k candidates, time remaining: 8.104594844221861mins
#
# Batch #1 >> Avg. speed: 1.0139762386285516s/1k candidates, time remaining: 5.359574204518935mins
#
# Batch #3 >> Avg. speed: 1.0146523906703149s/1k candidates, time remaining: 3.6835940390895114mins
#
# Batch #0 >> Avg. speed: 1.0506775388232836s/1k candidates, time remaining: 5.55356626695823mins
#
# Batch #2 >> Avg. speed: 1.112242309981688s/1k candidates, time remaining: 5.8789791778702085mins
#
# Batch #1 >> Avg. speed: 1.0112443933091142s/1k candidates, time remaining: 3.659727167532128mins
#
# Batch #3 >> Avg. speed: 1.0200022672417226s/1k candidates, time remaining: 2.003012452258145mins
#
# Batch #0 >> Avg. speed: 1.0443092756565975s/1k candidates, time remaining: 3.779390078910415mins
#
# Batch #2 >> Avg. speed: 1.1043411112175345s/1k candidates, time remaining: 3.9966472928666312mins
#
# Batch #1 >> Avg. speed: 1.0062332513579602s/1k candidates, time remaining: 1.9645362588429027mins
#
# Batch #3 >> Avg. speed: 1.01729782159027s/1k candidates, time remaining: 0.3022052728670829mins
#
# Batch #0 >> Avg. speed: 1.0473104878718527s/1k candidates, time remaining: 2.044734086171409mins
#
# Finished processing of batch 3/n
# Batch #2 >> Avg. speed: 1.096008450988469s/1k candidates, time remaining: 2.139810366094854mins
#
# Batch #1 >> Avg. speed: 1.0019966333395294s/1k candidates, time remaining: 0.2862704381451035mins
#
# Finished processing of batch 1/n
# Batch #0 >> Avg. speed: 1.0404721633368506s/1k candidates, time remaining: 0.2972628970653382mins
#
# Finished processing of batch 0/n
# Batch #2 >> Avg. speed: 1.09702328552836s/1k candidates, time remaining: 0.3134195526754524mins
#
# Finished processing of batch 2/n
# [0, 0, 0, 0]
# Time used: 675.4
# 1234140
# Number of Candidates to be processed: 1234140
# Candidates to be processed per batch: 617142
# Number of batches to be processed: 2
# Batch #0 >> Avg. speed: 61.2795352935791s/1k candidates, time remaining: 630.3029161691666mins
#
# Batch #1 >> Avg. speed: 1023.5183238983154s/1k candidates, time remaining: 10525.145980143547mins
#
# Batch #1 >> Avg. speed: 1.0204914444652857s/1k candidates, time remaining: 8.793200596761064mins
#
# Batch #0 >> Avg. speed: 1.029869507346644s/1k candidates, time remaining: 8.876479612804303mins
#
# Batch #0 >> Avg. speed: 1.012959043195049s/1k candidates, time remaining: 7.042462686607819mins
#
# Batch #1 >> Avg. speed: 1.1058225498724648s/1k candidates, time remaining: 7.6854298608619676mins
#
# Batch #0 >> Avg. speed: 1.0494587137310656s/1k candidates, time remaining: 5.547123923168294mins
#
# Batch #1 >> Avg. speed: 1.086056188543784s/1k candidates, time remaining: 5.737960660933374mins
#
# Batch #0 >> Avg. speed: 1.0404535788425162s/1k candidates, time remaining: 3.7654361836170276mins
#
# Batch #1 >> Avg. speed: 1.0605254547797698s/1k candidates, time remaining: 3.835531710605008mins
#
# Batch #0 >> Avg. speed: 1.0259205436598586s/1k candidates, time remaining: 2.0029730720900525mins
#
# Batch #1 >> Avg. speed: 1.066211276524438s/1k candidates, time remaining: 2.07907644884677mins
#
# Batch #0 >> Avg. speed: 1.0278479071034636s/1k candidates, time remaining: 0.2936561470594595mins
#
# Finished processing of batch 0/n
# Batch #1 >> Avg. speed: 1.066368002624679s/1k candidates, time remaining: 0.3021020551435715mins
#
# Finished processing of batch 1/n
# [0, 0]
# Time used: 657.2
# 1340877
# Number of Candidates to be processed: 1340877
# Candidates to be processed per batch: 617142
# Number of batches to be processed: 3
# Batch #0 >> Avg. speed: 81.84313774108887s/1k candidates, time remaining: 841.8139618635179mins
# Batch #2 >> Avg. speed: 1239.0975952148438s/1k candidates, time remaining: 2201.3188327789308mins
#
# Batch #1 >> Avg. speed: 1278.5797119140625s/1k candidates, time remaining: 13151.087342834475mins
#
# Batch #1 >> Avg. speed: 1.0170692136347985s/1k candidates, time remaining: 8.766153454625451mins
#
# Batch #0 >> Avg. speed: 1.0251774861668803s/1k candidates, time remaining: 8.836038925855213mins
#
# Batch #2 >> Avg. speed: 1.0912681171650198s/1k candidates, time remaining: 0.11991217827448293mins
#
# Finished processing of batch 2/n
# Batch #1 >> Avg. speed: 1.0117123956330445s/1k candidates, time remaining: 7.033795535652658mins
#
# Batch #0 >> Avg. speed: 1.084724488658593s/1k candidates, time remaining: 7.541402377467047mins
#
# Batch #1 >> Avg. speed: 1.005557302146741s/1k candidates, time remaining: 5.315074231957029mins
#
# Batch #0 >> Avg. speed: 1.0556025373793088s/1k candidates, time remaining: 5.579598331825812mins
#
# Batch #1 >> Avg. speed: 1.0166172868001744s/1k candidates, time remaining: 3.6791718481727242mins
#
# Batch #0 >> Avg. speed: 1.0621205563208473s/1k candidates, time remaining: 3.8438496973436904mins
#
# Batch #1 >> Avg. speed: 1.013125045130525s/1k candidates, time remaining: 1.977991567277999mins
#
# Batch #0 >> Avg. speed: 1.0564851120854706s/1k candidates, time remaining: 2.06264631666527mins
#
# Batch #1 >> Avg. speed: 1.0205677836849143s/1k candidates, time remaining: 0.29157621579878mins
#
# Finished processing of batch 1/n
# Batch #0 >> Avg. speed: 1.0499960978814629s/1k candidates, time remaining: 0.2999838851647339mins
#
# Finished processing of batch 0/n
# [0, 0, 0]
# Time used: 648.0
# 2244453
# Number of Candidates to be processed: 2244453
# Candidates to be processed per batch: 617142
# Number of batches to be processed: 4
# Batch #0 >> Avg. speed: 52.38080024719238s/1k candidates, time remaining: 538.7731971025468mins
#
# Batch #3 >> Avg. speed: 1645.2155113220215s/1k candidates, time remaining: 10776.901946139336mins
#
# Batch #2 >> Avg. speed: 1652.726411819458s/1k candidates, time remaining: 16999.4480540514mins
#
# Batch #1 >> Avg. speed: 1739.6018505096436s/1k candidates, time remaining: 17893.02275378704mins
#
# Batch #2 >> Avg. speed: 1.0071354717437324s/1k candidates, time remaining: 8.680534202141622mins
#
# Batch #1 >> Avg. speed: 1.0283283922150401s/1k candidates, time remaining: 8.863196690114506mins
#
# Batch #0 >> Avg. speed: 1.0386379233284084s/1k candidates, time remaining: 8.952054882431664mins
#
# Batch #3 >> Avg. speed: 1.208898383409202s/1k candidates, time remaining: 5.90399777658747mins
#
# Batch #2 >> Avg. speed: 1.0110585001865486s/1k candidates, time remaining: 7.029249414746954mins
#
# Batch #0 >> Avg. speed: 1.022649600144257s/1k candidates, time remaining: 7.109834991722929mins
#
# Batch #1 >> Avg. speed: 1.0260529451632834s/1k candidates, time remaining: 7.133496294188372mins
#
# Batch #3 >> Avg. speed: 1.1407974292621366s/1k candidates, time remaining: 3.670078422969707mins
#
# Batch #2 >> Avg. speed: 1.0112709819651247s/1k candidates, time remaining: 5.3452750293730595mins
#
# Batch #1 >> Avg. speed: 1.014556972694104s/1k candidates, time remaining: 5.362643790569225mins
#
# Batch #0 >> Avg. speed: 1.0216181159202655s/1k candidates, time remaining: 5.399966875319747mins
#
# Batch #3 >> Avg. speed: 1.0889114473457024s/1k candidates, time remaining: 1.6883027535371444mins
#
# Batch #2 >> Avg. speed: 1.0098164424436427s/1k candidates, time remaining: 3.654559365751624mins
#
# Batch #0 >> Avg. speed: 1.0117232361585995s/1k candidates, time remaining: 3.6614601157658435mins
#
# Batch #1 >> Avg. speed: 1.014924782572344s/1k candidates, time remaining: 3.6730466189553983mins
#
# Finished processing of batch 3/n
# Batch #0 >> Avg. speed: 1.0043309843685795s/1k candidates, time remaining: 1.9608223361817356mins
#
# Batch #1 >> Avg. speed: 1.0069588696996616s/1k candidates, time remaining: 1.9659529319059628mins
#
# Batch #2 >> Avg. speed: 1.0093789269246718s/1k candidates, time remaining: 1.9706777709634984mins
#
# Batch #0 >> Avg. speed: 1.0015113617407836s/1k candidates, time remaining: 0.28613179604934186mins
#
# Batch #1 >> Avg. speed: 1.0046554339606342s/1k candidates, time remaining: 0.28703005748255317mins
#
# Batch #2 >> Avg. speed: 1.0099216429716797s/1k candidates, time remaining: 0.2885346133970089mins
#
# Finished processing of batch 0/n
# Finished processing of batch 1/n
# Finished processing of batch 2/n
# [0, 0, 0, 0]
# Time used: 623.77
# 1103238
# Number of Candidates to be processed: 1103238
# Candidates to be processed per batch: 617142
# Number of batches to be processed: 2
# Batch #0 >> Avg. speed: 65.59491157531738s/1k candidates, time remaining: 674.689581990242mins
#
# Batch #1 >> Avg. speed: 885.7779502868652s/1k candidates, time remaining: 7176.218642044068mins
#
# Batch #1 >> Avg. speed: 0.9861530942300136s/1k candidates, time remaining: 6.345829417830523mins
#
# Batch #0 >> Avg. speed: 1.019648831564968s/1k candidates, time remaining: 8.788387267552846mins
#
# Batch #1 >> Avg. speed: 1.0141417567505517s/1k candidates, time remaining: 4.835698333988431mins
#
# Batch #0 >> Avg. speed: 1.0305660456332117s/1k candidates, time remaining: 7.164873023458821mins
#
# Batch #1 >> Avg. speed: 1.0159762666119585s/1k candidates, time remaining: 3.1511519885236505mins
#
# Batch #0 >> Avg. speed: 1.022035191276637s/1k candidates, time remaining: 5.40217141053092mins
#
# Batch #0 >> Avg. speed: 1.0179329487560758s/1k candidates, time remaining: 3.68393327264653mins
#
# Batch #1 >> Avg. speed: 1.0376645968671028s/1k candidates, time remaining: 1.4889795188645014mins
#
# Finished processing of batch 1/n
# Batch #0 >> Avg. speed: 1.029814431021315s/1k candidates, time remaining: 2.0105753679783147mins
#
# Batch #0 >> Avg. speed: 1.026831400456806s/1k candidates, time remaining: 0.29336573111050945mins
#
# Finished processing of batch 0/n
# [0, 0]
# Time used: 633.73

# %%
# Signal processing
if __name__ == '__main__':
    
    sample = "Res1ToRes2GluTo3Glu_M1-3000_R-0p3"
    isSig = 1
    temp_file = TFile(f"/home/xyan13/Trijet/TrijetAna/TrijetAna/outputs_3_jets/{sample}_ML_study.root","READ")
    temp_tree = temp_file.Get("Events")
    tot_evts = temp_tree.GetEntries()
    
    expect_time = 2 # in mins
    known_speed = 1.8 # sec per 1k candidates
    evt_batch = int(expect_time * 60 / known_speed * 1000)
    num_batch = math.ceil(tot_evts / evt_batch)
    print(f"Number of Candidates to be processed: {tot_evts}")
    print(f"Candidates to be processed per batch: {evt_batch}")
    print(f"Number of batches to be processed: {num_batch}")
    
    main_start = time.time()
    
    batch_size = evt_batch
    
#     multiprocessing way
#     p1 = multiprocessing.Process(target=select_trijet, args=(sample, ibatch_1))
#     p2 = multiprocessing.Process(target=select_trijet, args=(sample, ibatch_2))
#     p1.start()
#     p1.join()
#     p2.start()
#     p2.join()

    with concurrent.futures.ProcessPoolExecutor() as executor:
        results = [executor.submit(select_trijet, sample, batch_size, ibatch, isSig) for ibatch in range(num_batch)]
        status = [r.result() for r in results]
        print(status)

    print(f"Time used: {round(time.time() - main_start, 2)}")

# %%
# Dry-run, speed calculation
sample = "QCD_Pt_300to470"
isSig = 0
temp_file = TFile(f"/home/xyan13/Trijet/TrijetAna/TrijetAna/outputs_3_jets/{sample}_ML_study.root","READ")
temp_tree = temp_file.Get("Events")
tot_evts = temp_tree.GetEntries()

main_start = time.time()

batch_size = evt_batch

select_trijet(sample, 100000, 0, isSig)

print(f"Time used: {round(time.time() - main_start, 2)}")
