# %%
import ROOT
from ROOT import TFile, TTree, TH1F, TCanvas, TAxis, TLegend, THStack
import copy
import math
ROOT.gStyle.SetOptStat(0)
ROOT.disableJSVis()
# Out:
# Welcome to JupyROOT 6.22/06

# %%
def getRangeY(hist):
    global y_upper
    max_entry = hist.GetMaximum()
    if max_entry > y_upper:
        y_upper = max_entry * 1.1
def setHistOpt(hist, lcolor, lstyle):
    hist.SetLineWidth(2)
    hist.SetLineColor(lcolor)
    hist.SetLineStyle(lstyle)
def plot(h_plot, canvas, leg, xtitle, dopt, hlabel):
    global y_upper
    h_plot.Draw(dopt)
    h_plot.GetXaxis().SetTitle(xtitle)
    h_plot.GetXaxis().SetTitleOffset(1.2)
    h_plot.GetYaxis().SetTitle("Events")
    h_plot.SetMinimum(0.1)
    h_plot.SetMaximum(y_upper)
    leg.AddEntry(h_plot,hlabel)
    
hist_dic = {}
file_list = []
var2plot = ["dijet_eta", "dR_jj", "dEta_jj", "dPhi_jj", "dR_j0j2", "dEta_j0j2", "dPhi_j0j2", "dR_j1j2", "dEta_j1j2", "dPhi_j1j2", "jet_eta_0", 
 "jet_ptoverm_0", "jet_eta_1", "jet_ptoverm_1", "jet_eta_2", "jet_ptoverm_2", "dR_jj_j", "dEta_jj_j", "dPhi_jj_j", "jet_ptoverM_0", 
 "jet_ptoverM_1", "jet_ptoverM_2", "dijet_ptoverM"]
for var in var2plot:
    hist_dic[var] = THStack(var,var)
sample_list = ["QCD_Pt_300to470", "QCD_Pt_470to600","QCD_Pt_600to800","QCD_Pt_800to1000","QCD_Pt_1000to1400","QCD_Pt_1400to1800", "QCD_Pt_1800to2400",
               "QCD_Pt_2400to3200","QCD_Pt_3200toInf"]
sample_list.reverse()
for i, sample in enumerate(sample_list):
    file = TFile.Open(f"/home/xyan13/Trijet/TrijetAna/TrijetAna/ML_study_v2/{sample}.root")
    file_list.append(file)
    for var in var2plot:
        hist = file.Get(f"{sample}_{var}")
        setHistOpt(hist, i+1, 1)
        hist_dic[var].Add(hist)
        
nvar = len(hist_dic.keys())
nrow = math.ceil(nvar/3)
plot_list = []
leg_list = []
plot_name_list = []
for variable, hist in hist_dic.items():
    y_upper = 0
    getRangeY(hist)
    c = TCanvas(variable,"",800,600)
    leg = TLegend(0.6,0.8,0.87,0.85)
    leg.SetBorderSize(0)
    title = hist.GetTitle()
    print(title)
    plot(h_plot=hist, canvas=c, leg=leg, xtitle=title, dopt="HIST", hlabel="QCD (41.5 fb^{-1})")
    plot_list.append(c)
    leg_list.append(leg)
    plot_name_list.append(hist.GetName())
for i in range(0,len(plot_list)):
    plot_list[i].cd()
#     plot_list[i].SetLogy()
    leg_list[i].Draw()
    plot_list[i].Draw()
    plot_list[i].Print(f"{plot_name_list[i]}.png")

# %%
def getRangeY(hist):
    global y_upper
    entries = [hist.GetBinContent(i) for i in range(1,hist.GetNbinsX())]
    max_entry = max(entries)
    if max_entry > y_upper:
        y_upper = max_entry * 1.1
def plot(h_plot, canvas, leg, lcolor, lstyle, xtitle, dopt, hlabel):
    global y_upper
    h_plot.SetLineWidth(2)
    h_plot.SetLineColor(lcolor)
    h_plot.SetLineStyle(lstyle)
    h_plot.Draw(dopt)
    h_plot.GetXaxis().SetTitle(xtitle)
    h_plot.GetXaxis().SetTitleOffset(1.2)
    h_plot.GetYaxis().SetTitle("Events")
    h_plot.GetYaxis().SetRangeUser(0,y_upper)
    leg.AddEntry(h_plot,hlabel)
    
hist_dic = {}
file_list = []
var2plot = ["dijet_eta", "dR_jj", "dEta_jj", "dPhi_jj", "dR_j0j2", "dEta_j0j2", "dPhi_j0j2", "dR_j1j2", "dEta_j1j2", "dPhi_j1j2", "jet_eta_0", 
 "jet_ptoverm_0", "jet_eta_1", "jet_ptoverm_1", "jet_eta_2", "jet_ptoverm_2", "dR_jj_j", "dEta_jj_j", "dPhi_jj_j", "jet_ptoverM_0", 
 "jet_ptoverM_1", "jet_ptoverM_2", "dijet_ptoverM"]
sample_list = ["QCD_Pt_300to470", "QCD_Pt_470to600","QCD_Pt_600to800","QCD_Pt_800to1000","QCD_Pt_1000to1400","QCD_Pt_1400to1800","QCD_Pt_1800to2400","QCD_Pt_2400to3200","QCD_Pt_3200toInf"]
sample_list = ["QCD","Res1ToRes2GluTo3Glu_M1-3000_R-0p3_matched_3","Res1ToRes2GluTo3Glu_M1-3000_R-0p3_matched_0"]
for sample in sample_list:
    file = TFile.Open(f"/home/xyan13/Trijet/TrijetAna/TrijetAna/ML_study_v2/{sample}.root")
    file_list.append(file)
    hist_dic[sample] = {}
    file.ls()
    for var in var2plot:
        hist = file.Get(f"{sample}_{var}")
        print(hist)
        hist_dic[sample][var] = file.Get(f"{sample}_{var}")
        
nvar = len(hist_dic.keys())
nrow = math.ceil(nvar/3)
color_dic = {"QCD":4, "Res1ToRes2GluTo3Glu_M1-3000_R-0p3_matched_3":2, "Res1ToRes2GluTo3Glu_M1-3000_R-0p3_matched_0":6}
plot_list = []
leg_list = []
plot_name_list = []

for variable in var2plot:
    c = TCanvas(variable,"",800,600)
    leg = TLegend(0.6,0.8,0.87,0.85)
    leg.SetBorderSize(0)
    y_upper = 0
    for sample in sample_list:
        hist = hist_dic[sample][variable]
        print(type(hist))
        hist.Scale(1.0/hist.GetEntries())
        getRangeY(hist)
        plot(h_plot=hist, canvas=c, leg=leg, xtitle=title, dopt="HIST SAME", hlabel=sample)
        plot_list.append(c)
        leg_list.append(leg)
        plot_name_list.append(hist.GetName())
        
for i in range(0,len(plot_list)):
    plot_list[i].cd()
#     plot_list[i].SetLogy()
    leg_list[i].Draw()
    plot_list[i].Draw()
    plot_list[i].Print(f"{plot_name_list[i]}.png")
# Out:
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <cppyy.gbl.TObject object at 0x(nil)>
# <class cppyy.gbl.TObject at 0x55ca8b0edb30>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-e897d23e98d4> in <module>
#      48         hist = hist_dic[sample][variable]
#      49         print(type(hist))
# ---> 50         hist.Scale(1.0/hist.GetEntries())
#      51         getRangeY(hist)
#      52         plot(h_plot=hist, canvas=c, leg=leg, xtitle=title, dopt="HIST SAME", hlabel=sample)
#
# AttributeError: 'TObject' object has no attribute 'Scale'
# TFile**		/home/xyan13/Trijet/TrijetAna/TrijetAna/ML_study_v2/QCD.root
#  TFile*		/home/xyan13/Trijet/TrijetAna/TrijetAna/ML_study_v2/QCD.root
#   KEY: TH1F	QCD_Pt_1000to1400_m_jj;1	m_{jj} [GeV]
#   KEY: TH1F	QCD_Pt_1000to1400_dijet_eta;1	#eta_{jj}
#   KEY: TH1F	QCD_Pt_1000to1400_dR_jj;1	#Delta R_{jj}
#   KEY: TH1F	QCD_Pt_1000to1400_dEta_jj;1	#Delta #eta_{jj}
#   KEY: TH1F	QCD_Pt_1000to1400_dPhi_jj;1	#Delta #phi_{jj}
#   KEY: TH1F	QCD_Pt_1000to1400_dR_j0j2;1	#Delta R_{j0j2}
#   KEY: TH1F	QCD_Pt_1000to1400_dEta_j0j2;1	#Delta #eta_{j0j2}
#   KEY: TH1F	QCD_Pt_1000to1400_dPhi_j0j2;1	#Delta #phi_{j0j2}
#   KEY: TH1F	QCD_Pt_1000to1400_dR_j1j2;1	#Delta R_{j1j2}
#   KEY: TH1F	QCD_Pt_1000to1400_dEta_j1j2;1	#Delta #eta_{j1j2}
#   KEY: TH1F	QCD_Pt_1000to1400_dPhi_j1j2;1	#Delta #phi_{j1j2}
#   KEY: TH1F	QCD_Pt_1000to1400_jet_eta_0;1	#eta_{j0}
#   KEY: TH1F	QCD_Pt_1000to1400_jet_eta_1;1	#eta_{j1}
#   KEY: TH1F	QCD_Pt_1000to1400_jet_eta_2;1	#eta_{j2}
#   KEY: TH1F	QCD_Pt_1000to1400_jet_ptoverm_0;1	p^{j0}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_1000to1400_jet_ptoverm_1;1	p^{j1}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_1000to1400_jet_ptoverm_2;1	p^{j2}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_1000to1400_dR_jj_j;1	#Delta R_{jj-j}
#   KEY: TH1F	QCD_Pt_1000to1400_dEta_jj_j;1	#Delta #eta_{jj-j}
#   KEY: TH1F	QCD_Pt_1000to1400_dPhi_jj_j;1	#Delta #phi_{jj-j}
#   KEY: TH1F	QCD_Pt_1000to1400_jet_ptoverM_0;1	p^{j0}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_1000to1400_jet_ptoverM_1;1	p^{j1}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_1000to1400_jet_ptoverM_2;1	p^{j2}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_1000to1400_dijet_ptoverM;1	p^{jj}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_1000to1400_M_jjj;1	M_{jjj}
#   KEY: TH1F	QCD_Pt_1400to1800_m_jj;1	m_{jj} [GeV]
#   KEY: TH1F	QCD_Pt_1400to1800_dijet_eta;1	#eta_{jj}
#   KEY: TH1F	QCD_Pt_1400to1800_dR_jj;1	#Delta R_{jj}
#   KEY: TH1F	QCD_Pt_1400to1800_dEta_jj;1	#Delta #eta_{jj}
#   KEY: TH1F	QCD_Pt_1400to1800_dPhi_jj;1	#Delta #phi_{jj}
#   KEY: TH1F	QCD_Pt_1400to1800_dR_j0j2;1	#Delta R_{j0j2}
#   KEY: TH1F	QCD_Pt_1400to1800_dEta_j0j2;1	#Delta #eta_{j0j2}
#   KEY: TH1F	QCD_Pt_1400to1800_dPhi_j0j2;1	#Delta #phi_{j0j2}
#   KEY: TH1F	QCD_Pt_1400to1800_dR_j1j2;1	#Delta R_{j1j2}
#   KEY: TH1F	QCD_Pt_1400to1800_dEta_j1j2;1	#Delta #eta_{j1j2}
#   KEY: TH1F	QCD_Pt_1400to1800_dPhi_j1j2;1	#Delta #phi_{j1j2}
#   KEY: TH1F	QCD_Pt_1400to1800_jet_eta_0;1	#eta_{j0}
#   KEY: TH1F	QCD_Pt_1400to1800_jet_eta_1;1	#eta_{j1}
#   KEY: TH1F	QCD_Pt_1400to1800_jet_eta_2;1	#eta_{j2}
#   KEY: TH1F	QCD_Pt_1400to1800_jet_ptoverm_0;1	p^{j0}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_1400to1800_jet_ptoverm_1;1	p^{j1}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_1400to1800_jet_ptoverm_2;1	p^{j2}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_1400to1800_dR_jj_j;1	#Delta R_{jj-j}
#   KEY: TH1F	QCD_Pt_1400to1800_dEta_jj_j;1	#Delta #eta_{jj-j}
#   KEY: TH1F	QCD_Pt_1400to1800_dPhi_jj_j;1	#Delta #phi_{jj-j}
#   KEY: TH1F	QCD_Pt_1400to1800_jet_ptoverM_0;1	p^{j0}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_1400to1800_jet_ptoverM_1;1	p^{j1}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_1400to1800_jet_ptoverM_2;1	p^{j2}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_1400to1800_dijet_ptoverM;1	p^{jj}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_1400to1800_M_jjj;1	M_{jjj}
#   KEY: TH1F	QCD_Pt_1800to2400_m_jj;1	m_{jj} [GeV]
#   KEY: TH1F	QCD_Pt_1800to2400_dijet_eta;1	#eta_{jj}
#   KEY: TH1F	QCD_Pt_1800to2400_dR_jj;1	#Delta R_{jj}
#   KEY: TH1F	QCD_Pt_1800to2400_dEta_jj;1	#Delta #eta_{jj}
#   KEY: TH1F	QCD_Pt_1800to2400_dPhi_jj;1	#Delta #phi_{jj}
#   KEY: TH1F	QCD_Pt_1800to2400_dR_j0j2;1	#Delta R_{j0j2}
#   KEY: TH1F	QCD_Pt_1800to2400_dEta_j0j2;1	#Delta #eta_{j0j2}
#   KEY: TH1F	QCD_Pt_1800to2400_dPhi_j0j2;1	#Delta #phi_{j0j2}
#   KEY: TH1F	QCD_Pt_1800to2400_dR_j1j2;1	#Delta R_{j1j2}
#   KEY: TH1F	QCD_Pt_1800to2400_dEta_j1j2;1	#Delta #eta_{j1j2}
#   KEY: TH1F	QCD_Pt_1800to2400_dPhi_j1j2;1	#Delta #phi_{j1j2}
#   KEY: TH1F	QCD_Pt_1800to2400_jet_eta_0;1	#eta_{j0}
#   KEY: TH1F	QCD_Pt_1800to2400_jet_eta_1;1	#eta_{j1}
#   KEY: TH1F	QCD_Pt_1800to2400_jet_eta_2;1	#eta_{j2}
#   KEY: TH1F	QCD_Pt_1800to2400_jet_ptoverm_0;1	p^{j0}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_1800to2400_jet_ptoverm_1;1	p^{j1}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_1800to2400_jet_ptoverm_2;1	p^{j2}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_1800to2400_dR_jj_j;1	#Delta R_{jj-j}
#   KEY: TH1F	QCD_Pt_1800to2400_dEta_jj_j;1	#Delta #eta_{jj-j}
#   KEY: TH1F	QCD_Pt_1800to2400_dPhi_jj_j;1	#Delta #phi_{jj-j}
#   KEY: TH1F	QCD_Pt_1800to2400_jet_ptoverM_0;1	p^{j0}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_1800to2400_jet_ptoverM_1;1	p^{j1}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_1800to2400_jet_ptoverM_2;1	p^{j2}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_1800to2400_dijet_ptoverM;1	p^{jj}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_1800to2400_M_jjj;1	M_{jjj}
#   KEY: TH1F	QCD_Pt_2400to3200_m_jj;1	m_{jj} [GeV]
#   KEY: TH1F	QCD_Pt_2400to3200_dijet_eta;1	#eta_{jj}
#   KEY: TH1F	QCD_Pt_2400to3200_dR_jj;1	#Delta R_{jj}
#   KEY: TH1F	QCD_Pt_2400to3200_dEta_jj;1	#Delta #eta_{jj}
#   KEY: TH1F	QCD_Pt_2400to3200_dPhi_jj;1	#Delta #phi_{jj}
#   KEY: TH1F	QCD_Pt_2400to3200_dR_j0j2;1	#Delta R_{j0j2}
#   KEY: TH1F	QCD_Pt_2400to3200_dEta_j0j2;1	#Delta #eta_{j0j2}
#   KEY: TH1F	QCD_Pt_2400to3200_dPhi_j0j2;1	#Delta #phi_{j0j2}
#   KEY: TH1F	QCD_Pt_2400to3200_dR_j1j2;1	#Delta R_{j1j2}
#   KEY: TH1F	QCD_Pt_2400to3200_dEta_j1j2;1	#Delta #eta_{j1j2}
#   KEY: TH1F	QCD_Pt_2400to3200_dPhi_j1j2;1	#Delta #phi_{j1j2}
#   KEY: TH1F	QCD_Pt_2400to3200_jet_eta_0;1	#eta_{j0}
#   KEY: TH1F	QCD_Pt_2400to3200_jet_eta_1;1	#eta_{j1}
#   KEY: TH1F	QCD_Pt_2400to3200_jet_eta_2;1	#eta_{j2}
#   KEY: TH1F	QCD_Pt_2400to3200_jet_ptoverm_0;1	p^{j0}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_2400to3200_jet_ptoverm_1;1	p^{j1}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_2400to3200_jet_ptoverm_2;1	p^{j2}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_2400to3200_dR_jj_j;1	#Delta R_{jj-j}
#   KEY: TH1F	QCD_Pt_2400to3200_dEta_jj_j;1	#Delta #eta_{jj-j}
#   KEY: TH1F	QCD_Pt_2400to3200_dPhi_jj_j;1	#Delta #phi_{jj-j}
#   KEY: TH1F	QCD_Pt_2400to3200_jet_ptoverM_0;1	p^{j0}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_2400to3200_jet_ptoverM_1;1	p^{j1}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_2400to3200_jet_ptoverM_2;1	p^{j2}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_2400to3200_dijet_ptoverM;1	p^{jj}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_2400to3200_M_jjj;1	M_{jjj}
#   KEY: TH1F	QCD_Pt_300to470_m_jj;1	m_{jj} [GeV]
#   KEY: TH1F	QCD_Pt_300to470_dijet_eta;1	#eta_{jj}
#   KEY: TH1F	QCD_Pt_300to470_dR_jj;1	#Delta R_{jj}
#   KEY: TH1F	QCD_Pt_300to470_dEta_jj;1	#Delta #eta_{jj}
#   KEY: TH1F	QCD_Pt_300to470_dPhi_jj;1	#Delta #phi_{jj}
#   KEY: TH1F	QCD_Pt_300to470_dR_j0j2;1	#Delta R_{j0j2}
#   KEY: TH1F	QCD_Pt_300to470_dEta_j0j2;1	#Delta #eta_{j0j2}
#   KEY: TH1F	QCD_Pt_300to470_dPhi_j0j2;1	#Delta #phi_{j0j2}
#   KEY: TH1F	QCD_Pt_300to470_dR_j1j2;1	#Delta R_{j1j2}
#   KEY: TH1F	QCD_Pt_300to470_dEta_j1j2;1	#Delta #eta_{j1j2}
#   KEY: TH1F	QCD_Pt_300to470_dPhi_j1j2;1	#Delta #phi_{j1j2}
#   KEY: TH1F	QCD_Pt_300to470_jet_eta_0;1	#eta_{j0}
#   KEY: TH1F	QCD_Pt_300to470_jet_eta_1;1	#eta_{j1}
#   KEY: TH1F	QCD_Pt_300to470_jet_eta_2;1	#eta_{j2}
#   KEY: TH1F	QCD_Pt_300to470_jet_ptoverm_0;1	p^{j0}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_300to470_jet_ptoverm_1;1	p^{j1}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_300to470_jet_ptoverm_2;1	p^{j2}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_300to470_dR_jj_j;1	#Delta R_{jj-j}
#   KEY: TH1F	QCD_Pt_300to470_dEta_jj_j;1	#Delta #eta_{jj-j}
#   KEY: TH1F	QCD_Pt_300to470_dPhi_jj_j;1	#Delta #phi_{jj-j}
#   KEY: TH1F	QCD_Pt_300to470_jet_ptoverM_0;1	p^{j0}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_300to470_jet_ptoverM_1;1	p^{j1}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_300to470_jet_ptoverM_2;1	p^{j2}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_300to470_dijet_ptoverM;1	p^{jj}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_300to470_M_jjj;1	M_{jjj}
#   KEY: TH1F	QCD_Pt_3200toInf_m_jj;1	m_{jj} [GeV]
#   KEY: TH1F	QCD_Pt_3200toInf_dijet_eta;1	#eta_{jj}
#   KEY: TH1F	QCD_Pt_3200toInf_dR_jj;1	#Delta R_{jj}
#   KEY: TH1F	QCD_Pt_3200toInf_dEta_jj;1	#Delta #eta_{jj}
#   KEY: TH1F	QCD_Pt_3200toInf_dPhi_jj;1	#Delta #phi_{jj}
#   KEY: TH1F	QCD_Pt_3200toInf_dR_j0j2;1	#Delta R_{j0j2}
#   KEY: TH1F	QCD_Pt_3200toInf_dEta_j0j2;1	#Delta #eta_{j0j2}
#   KEY: TH1F	QCD_Pt_3200toInf_dPhi_j0j2;1	#Delta #phi_{j0j2}
#   KEY: TH1F	QCD_Pt_3200toInf_dR_j1j2;1	#Delta R_{j1j2}
#   KEY: TH1F	QCD_Pt_3200toInf_dEta_j1j2;1	#Delta #eta_{j1j2}
#   KEY: TH1F	QCD_Pt_3200toInf_dPhi_j1j2;1	#Delta #phi_{j1j2}
#   KEY: TH1F	QCD_Pt_3200toInf_jet_eta_0;1	#eta_{j0}
#   KEY: TH1F	QCD_Pt_3200toInf_jet_eta_1;1	#eta_{j1}
#   KEY: TH1F	QCD_Pt_3200toInf_jet_eta_2;1	#eta_{j2}
#   KEY: TH1F	QCD_Pt_3200toInf_jet_ptoverm_0;1	p^{j0}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_3200toInf_jet_ptoverm_1;1	p^{j1}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_3200toInf_jet_ptoverm_2;1	p^{j2}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_3200toInf_dR_jj_j;1	#Delta R_{jj-j}
#   KEY: TH1F	QCD_Pt_3200toInf_dEta_jj_j;1	#Delta #eta_{jj-j}
#   KEY: TH1F	QCD_Pt_3200toInf_dPhi_jj_j;1	#Delta #phi_{jj-j}
#   KEY: TH1F	QCD_Pt_3200toInf_jet_ptoverM_0;1	p^{j0}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_3200toInf_jet_ptoverM_1;1	p^{j1}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_3200toInf_jet_ptoverM_2;1	p^{j2}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_3200toInf_dijet_ptoverM;1	p^{jj}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_3200toInf_M_jjj;1	M_{jjj}
#   KEY: TH1F	QCD_Pt_470to600_m_jj;1	m_{jj} [GeV]
#   KEY: TH1F	QCD_Pt_470to600_dijet_eta;1	#eta_{jj}
#   KEY: TH1F	QCD_Pt_470to600_dR_jj;1	#Delta R_{jj}
#   KEY: TH1F	QCD_Pt_470to600_dEta_jj;1	#Delta #eta_{jj}
#   KEY: TH1F	QCD_Pt_470to600_dPhi_jj;1	#Delta #phi_{jj}
#   KEY: TH1F	QCD_Pt_470to600_dR_j0j2;1	#Delta R_{j0j2}
#   KEY: TH1F	QCD_Pt_470to600_dEta_j0j2;1	#Delta #eta_{j0j2}
#   KEY: TH1F	QCD_Pt_470to600_dPhi_j0j2;1	#Delta #phi_{j0j2}
#   KEY: TH1F	QCD_Pt_470to600_dR_j1j2;1	#Delta R_{j1j2}
#   KEY: TH1F	QCD_Pt_470to600_dEta_j1j2;1	#Delta #eta_{j1j2}
#   KEY: TH1F	QCD_Pt_470to600_dPhi_j1j2;1	#Delta #phi_{j1j2}
#   KEY: TH1F	QCD_Pt_470to600_jet_eta_0;1	#eta_{j0}
#   KEY: TH1F	QCD_Pt_470to600_jet_eta_1;1	#eta_{j1}
#   KEY: TH1F	QCD_Pt_470to600_jet_eta_2;1	#eta_{j2}
#   KEY: TH1F	QCD_Pt_470to600_jet_ptoverm_0;1	p^{j0}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_470to600_jet_ptoverm_1;1	p^{j1}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_470to600_jet_ptoverm_2;1	p^{j2}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_470to600_dR_jj_j;1	#Delta R_{jj-j}
#   KEY: TH1F	QCD_Pt_470to600_dEta_jj_j;1	#Delta #eta_{jj-j}
#   KEY: TH1F	QCD_Pt_470to600_dPhi_jj_j;1	#Delta #phi_{jj-j}
#   KEY: TH1F	QCD_Pt_470to600_jet_ptoverM_0;1	p^{j0}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_470to600_jet_ptoverM_1;1	p^{j1}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_470to600_jet_ptoverM_2;1	p^{j2}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_470to600_dijet_ptoverM;1	p^{jj}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_470to600_M_jjj;1	M_{jjj}
#   KEY: TH1F	QCD_Pt_600to800_m_jj;1	m_{jj} [GeV]
#   KEY: TH1F	QCD_Pt_600to800_dijet_eta;1	#eta_{jj}
#   KEY: TH1F	QCD_Pt_600to800_dR_jj;1	#Delta R_{jj}
#   KEY: TH1F	QCD_Pt_600to800_dEta_jj;1	#Delta #eta_{jj}
#   KEY: TH1F	QCD_Pt_600to800_dPhi_jj;1	#Delta #phi_{jj}
#   KEY: TH1F	QCD_Pt_600to800_dR_j0j2;1	#Delta R_{j0j2}
#   KEY: TH1F	QCD_Pt_600to800_dEta_j0j2;1	#Delta #eta_{j0j2}
#   KEY: TH1F	QCD_Pt_600to800_dPhi_j0j2;1	#Delta #phi_{j0j2}
#   KEY: TH1F	QCD_Pt_600to800_dR_j1j2;1	#Delta R_{j1j2}
#   KEY: TH1F	QCD_Pt_600to800_dEta_j1j2;1	#Delta #eta_{j1j2}
#   KEY: TH1F	QCD_Pt_600to800_dPhi_j1j2;1	#Delta #phi_{j1j2}
#   KEY: TH1F	QCD_Pt_600to800_jet_eta_0;1	#eta_{j0}
#   KEY: TH1F	QCD_Pt_600to800_jet_eta_1;1	#eta_{j1}
#   KEY: TH1F	QCD_Pt_600to800_jet_eta_2;1	#eta_{j2}
#   KEY: TH1F	QCD_Pt_600to800_jet_ptoverm_0;1	p^{j0}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_600to800_jet_ptoverm_1;1	p^{j1}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_600to800_jet_ptoverm_2;1	p^{j2}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_600to800_dR_jj_j;1	#Delta R_{jj-j}
#   KEY: TH1F	QCD_Pt_600to800_dEta_jj_j;1	#Delta #eta_{jj-j}
#   KEY: TH1F	QCD_Pt_600to800_dPhi_jj_j;1	#Delta #phi_{jj-j}
#   KEY: TH1F	QCD_Pt_600to800_jet_ptoverM_0;1	p^{j0}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_600to800_jet_ptoverM_1;1	p^{j1}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_600to800_jet_ptoverM_2;1	p^{j2}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_600to800_dijet_ptoverM;1	p^{jj}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_600to800_M_jjj;1	M_{jjj}
#   KEY: TH1F	QCD_Pt_800to1000_m_jj;1	m_{jj} [GeV]
#   KEY: TH1F	QCD_Pt_800to1000_dijet_eta;1	#eta_{jj}
#   KEY: TH1F	QCD_Pt_800to1000_dR_jj;1	#Delta R_{jj}
#   KEY: TH1F	QCD_Pt_800to1000_dEta_jj;1	#Delta #eta_{jj}
#   KEY: TH1F	QCD_Pt_800to1000_dPhi_jj;1	#Delta #phi_{jj}
#   KEY: TH1F	QCD_Pt_800to1000_dR_j0j2;1	#Delta R_{j0j2}
#   KEY: TH1F	QCD_Pt_800to1000_dEta_j0j2;1	#Delta #eta_{j0j2}
#   KEY: TH1F	QCD_Pt_800to1000_dPhi_j0j2;1	#Delta #phi_{j0j2}
#   KEY: TH1F	QCD_Pt_800to1000_dR_j1j2;1	#Delta R_{j1j2}
#   KEY: TH1F	QCD_Pt_800to1000_dEta_j1j2;1	#Delta #eta_{j1j2}
#   KEY: TH1F	QCD_Pt_800to1000_dPhi_j1j2;1	#Delta #phi_{j1j2}
#   KEY: TH1F	QCD_Pt_800to1000_jet_eta_0;1	#eta_{j0}
#   KEY: TH1F	QCD_Pt_800to1000_jet_eta_1;1	#eta_{j1}
#   KEY: TH1F	QCD_Pt_800to1000_jet_eta_2;1	#eta_{j2}
#   KEY: TH1F	QCD_Pt_800to1000_jet_ptoverm_0;1	p^{j0}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_800to1000_jet_ptoverm_1;1	p^{j1}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_800to1000_jet_ptoverm_2;1	p^{j2}_{T}/m_{jj}
#   KEY: TH1F	QCD_Pt_800to1000_dR_jj_j;1	#Delta R_{jj-j}
#   KEY: TH1F	QCD_Pt_800to1000_dEta_jj_j;1	#Delta #eta_{jj-j}
#   KEY: TH1F	QCD_Pt_800to1000_dPhi_jj_j;1	#Delta #phi_{jj-j}
#   KEY: TH1F	QCD_Pt_800to1000_jet_ptoverM_0;1	p^{j0}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_800to1000_jet_ptoverM_1;1	p^{j1}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_800to1000_jet_ptoverM_2;1	p^{j2}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_800to1000_dijet_ptoverM;1	p^{jj}_{T}/M_{jjj}
#   KEY: TH1F	QCD_Pt_800to1000_M_jjj;1	M_{jjj}
# TFile**		/home/xyan13/Trijet/TrijetAna/TrijetAna/ML_study_v2/Res1ToRes2GluTo3Glu_M1-3000_R-0p3_matched_3.root
#  TFile*		/home/xyan13/Trijet/TrijetAna/TrijetAna/ML_study_v2/Res1ToRes2GluTo3Glu_M1-3000_R-0p3_matched_3.root
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_m_jj;1	m_{jj} [GeV]
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dijet_eta;1	#eta_{jj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dR_jj;1	#Delta R_{jj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dEta_jj;1	#Delta #eta_{jj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dPhi_jj;1	#Delta #phi_{jj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dR_j0j2;1	#Delta R_{j0j2}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dEta_j0j2;1	#Delta #eta_{j0j2}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dPhi_j0j2;1	#Delta #phi_{j0j2}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dR_j1j2;1	#Delta R_{j1j2}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dEta_j1j2;1	#Delta #eta_{j1j2}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dPhi_j1j2;1	#Delta #phi_{j1j2}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_eta_0;1	#eta_{j0}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_eta_1;1	#eta_{j1}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_eta_2;1	#eta_{j2}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_ptoverm_0;1	p^{j0}_{T}/m_{jj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_ptoverm_1;1	p^{j1}_{T}/m_{jj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_ptoverm_2;1	p^{j2}_{T}/m_{jj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dR_jj_j;1	#Delta R_{jj-j}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dEta_jj_j;1	#Delta #eta_{jj-j}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dPhi_jj_j;1	#Delta #phi_{jj-j}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_ptoverM_0;1	p^{j0}_{T}/M_{jjj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_ptoverM_1;1	p^{j1}_{T}/M_{jjj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_ptoverM_2;1	p^{j2}_{T}/M_{jjj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dijet_ptoverM;1	p^{jj}_{T}/M_{jjj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_M_jjj;1	M_{jjj}
# TFile**		/home/xyan13/Trijet/TrijetAna/TrijetAna/ML_study_v2/Res1ToRes2GluTo3Glu_M1-3000_R-0p3_matched_0.root
#  TFile*		/home/xyan13/Trijet/TrijetAna/TrijetAna/ML_study_v2/Res1ToRes2GluTo3Glu_M1-3000_R-0p3_matched_0.root
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_m_jj;1	m_{jj} [GeV]
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dijet_eta;1	#eta_{jj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dR_jj;1	#Delta R_{jj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dEta_jj;1	#Delta #eta_{jj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dPhi_jj;1	#Delta #phi_{jj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dR_j0j2;1	#Delta R_{j0j2}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dEta_j0j2;1	#Delta #eta_{j0j2}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dPhi_j0j2;1	#Delta #phi_{j0j2}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dR_j1j2;1	#Delta R_{j1j2}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dEta_j1j2;1	#Delta #eta_{j1j2}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dPhi_j1j2;1	#Delta #phi_{j1j2}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_eta_0;1	#eta_{j0}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_eta_1;1	#eta_{j1}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_eta_2;1	#eta_{j2}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_ptoverm_0;1	p^{j0}_{T}/m_{jj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_ptoverm_1;1	p^{j1}_{T}/m_{jj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_ptoverm_2;1	p^{j2}_{T}/m_{jj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dR_jj_j;1	#Delta R_{jj-j}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dEta_jj_j;1	#Delta #eta_{jj-j}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dPhi_jj_j;1	#Delta #phi_{jj-j}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_ptoverM_0;1	p^{j0}_{T}/M_{jjj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_ptoverM_1;1	p^{j1}_{T}/M_{jjj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_jet_ptoverM_2;1	p^{j2}_{T}/M_{jjj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_dijet_ptoverM;1	p^{jj}_{T}/M_{jjj}
#   KEY: TH1F	Res1ToRes2GluTo3Glu_M1-3000_R-0p3_M_jjj;1	M_{jjj}
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dijet_eta
