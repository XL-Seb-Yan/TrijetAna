# %%
import ROOT
from ROOT import TFile, TTree, TH1F, TCanvas, TAxis, TLegend, TTreeReader, TTreeReaderValue
import copy
ROOT.gStyle.SetOptStat(0)
# Out:
# Welcome to JupyROOT 6.22/06

# %%
h_m_jj = TH1F("mjj","mjj",100,0,3000)
h_m_jjj = TH1F("mjjj","mjjj",100,0,6000)
file = TFile.Open(f"/home/xyan13/Trijet/TrijetAna/TrijetAna/ML_study_v2/QCD_Pt_300to470.root")
file.ls()
# Out:
# TFile**		/home/xyan13/Trijet/TrijetAna/TrijetAna/ML_study_v2/QCD_Pt_300to470.root
#  TFile*		/home/xyan13/Trijet/TrijetAna/TrijetAna/ML_study_v2/QCD_Pt_300to470.root
#   KEY: TH1F	QCD_Pt_300to470_m_jj;1
#   KEY: TH1F	QCD_Pt_300to470_dijet_eta;1
#   KEY: TH1F	QCD_Pt_300to470_dR_jj;1
#   KEY: TH1F	QCD_Pt_300to470_dEta_jj;1
#   KEY: TH1F	QCD_Pt_300to470_dPhi_jj;1
#   KEY: TH1F	QCD_Pt_300to470_dR_j0j2;1
#   KEY: TH1F	QCD_Pt_300to470_dEta_j0j2;1
#   KEY: TH1F	QCD_Pt_300to470_dPhi_j0j2;1
#   KEY: TH1F	QCD_Pt_300to470_dR_j1j2;1
#   KEY: TH1F	QCD_Pt_300to470_dEta_j1j2;1
#   KEY: TH1F	QCD_Pt_300to470_dPhi_j1j2;1
#   KEY: TH1F	QCD_Pt_300to470_jet_eta_0;1
#   KEY: TH1F	QCD_Pt_300to470_jet_eta_1;1
#   KEY: TH1F	QCD_Pt_300to470_jet_eta_2;1
#   KEY: TH1F	QCD_Pt_300to470_jet_ptoverm_0;1
#   KEY: TH1F	QCD_Pt_300to470_jet_ptoverm_1;1
#   KEY: TH1F	QCD_Pt_300to470_jet_ptoverm_2;1
#   KEY: TH1F	QCD_Pt_300to470_dR_jj_j;1
#   KEY: TH1F	QCD_Pt_300to470_dEta_jj_j;1
#   KEY: TH1F	QCD_Pt_300to470_dPhi_jj_j;1
#   KEY: TH1F	QCD_Pt_300to470_jet_ptoverM_0;1
#   KEY: TH1F	QCD_Pt_300to470_jet_ptoverM_1;1
#   KEY: TH1F	QCD_Pt_300to470_jet_ptoverM_2;1
#   KEY: TH1F	QCD_Pt_300to470_dijet_ptoverM;1
#   KEY: TH1F	QCD_Pt_300to470_M_jjj;1

# %%
import math
ROOT.disableJSVis()
c = TCanvas("c","",1200,900)
c.cd()
file.Get("QCD_Pt_300to470_M_jjj").Draw()
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
c1 = TCanvas("c1","",1200,900)
c1.cd()
h_m_jjj.Draw()
c1.Draw()
